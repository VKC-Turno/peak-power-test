# %%
from pathlib import Path
import sys

COMMON_UTILS_PARENT = Path("/home/kcv/Desktop")
if str(COMMON_UTILS_PARENT) not in sys.path:
    sys.path.insert(0, str(COMMON_UTILS_PARENT))

from post_processing_common_utils.stitch_detail_data import stitch_detail_sheets

# %%
input_dir = Path("/home/kcv/Desktop/peak_power_test/Data")
output_dir = Path("/home/kcv/Desktop/peak_power_test/stitched_detail_data")

stitch_detail_sheets(
    input_dir=input_dir,
    output_dir=output_dir,
    engine="openpyxl",          # optional
    usecols=None,               # or ["Cycle No", "Step No", ...]
    sheet_pattern=r"detail.*",  # optional regex override
)
# Out:
# [ok] appended RD_LFP_PeakPower_REPT_TS_150_0001_0_100.xlsx → RD_LFP_PeakPower_REPT_TS_150_0001_0_100.csv
# [ok] appended RD_LFP_PeakPower_REPT_TS_150_0003_0_100.xlsx → RD_LFP_PeakPower_REPT_TS_150_0003_0_100.csv
# [ok] appended RD_LFP_PeakPower_REPT_TS_150_0004_0_100.xlsx → RD_LFP_PeakPower_REPT_TS_150_0004_0_100.csv
# [ok] appended RD_LFP_PeakPower_REPT_TS_150_0007_0_100.xlsx → RD_LFP_PeakPower_REPT_TS_150_0007_0_100.csv
# [ok] appended RD_LFP_PeakPower_REPT_TS_150_0011_0_100.xlsx → RD_LFP_PeakPower_REPT_TS_150_0011_0_100.csv
# [ok] appended RD_LFP_PeakPower_REPT_TS_150_0012_0_100.xlsx → RD_LFP_PeakPower_REPT_TS_150_0012_0_100.csv
# [ok] appended RD_LFP_PeakPower_REPT_TS_150_0025_0_100.xlsx → RD_LFP_PeakPower_REPT_TS_150_0025_0_100.csv
# [ok] appended RD_LFP_PeakPower_REPT_TS_150_0034_0_100.xlsx → RD_LFP_PeakPower_REPT_TS_150_0034_0_100.csv
# [ok] appended RD_LFP_PeakPower_REPT_TS_150_0040_0_100.xlsx → RD_LFP_PeakPower_REPT_TS_150_0040_0_100.csv
# [ok] appended RD_LFP_PeakPower_REPT_TS_150_0043_0_100.xlsx → RD_LFP_PeakPower_REPT_TS_150_0043_0_100.csv
# [ok] appended RD_LFP_PeakPower_REPT_TS_150_0046_0_100.xlsx → RD_LFP_PeakPower_REPT_TS_150_0046_0_100.csv
# [ok] appended RD_LFP_PeakPower_REPT_TS_150_0049_0_100.xlsx → RD_LFP_PeakPower_REPT_TS_150_0049_0_100.csv
# [ok] appended RD_LFP_PeakPower_REPT_TS_150_0050_0_100.xlsx → RD_LFP_PeakPower_REPT_TS_150_0050_0_100.csv
# [ok] appended RD_LFP_PeakPower_REPT_TS_150_0056_0_100.xlsx → RD_LFP_PeakPower_REPT_TS_150_0056_0_100.csv
# [ok] appended RD_LFP_PeakPower_REPT_TS_150_0057_0_100.xlsx → RD_LFP_PeakPower_REPT_TS_150_0057_0_100.csv
# [ok] appended RD_LFP_PeakPower_REPT_TS_150_0065_0_100.xlsx → RD_LFP_PeakPower_REPT_TS_150_0065_0_100.csv
# [ok] appended RD_LFP_PeakPower_REPT_TS_150_0074_0_100.xlsx → RD_LFP_PeakPower_REPT_TS_150_0074_0_100.csv
# [ok] appended RD_LFP_PeakPower_REPT_TS_150_0078_0_100.xlsx → RD_LFP_PeakPower_REPT_TS_150_0078_0_100.csv
# [ok] appended RD_LFP_PeakPower_REPT_TS_150_0080_0_100.xlsx → RD_LFP_PeakPower_REPT_TS_150_0080_0_100.csv
# [ok] appended RD_LFP_PeakPower_REPT_TS_150_0087_0_100.xlsx → RD_LFP_PeakPower_REPT_TS_150_0087_0_100.csv
# [ok] appended RD_LFP_PeakPower_REPT_TS_150_0090_0_100.xlsx → RD_LFP_PeakPower_REPT_TS_150_0090_0_100.csv
#
# Done. Per-cell CSVs saved in: /home/kcv/Desktop/peak_power_test/stitched_detail_data
